# %%
import pandas as pd
import numpy as np
inputfile = "../Data/train_flatten.csv"

# %%
df = pd.read_csv(inputfile, delimiter=',', skipinitialspace=True)
# Out:
# /Users/bpc_msds2019/miniconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3018: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'channelGrouping', 'date', 'fullVisitorId', 'sessionId',
#        'socialEngagementType', 'visitId', 'visitNumber', 'visitStartTime',
#        'bounces', 'hits', 'newVisits', 'pageviews', 'transactionRevenue',
#        'visits', 'browser', 'deviceCategory', 'isMobile', 'operatingSystem',
#        'adContent', 'adwordsClickInfo', 'campaign', 'isTrueDirect', 'keyword',
#        'medium', 'referralPath', 'source', 'city', 'continent', 'country',
#        'metro', 'networkDomain', 'region', 'subContinent'],
#       dtype='object')

# %%
df.groupby('fullVisitorId').count().sort_values(by='visitNumber',ascending=False)
# Out:
#                      Unnamed: 0  channelGrouping  date  sessionId  \
# fullVisitorId
# 1957458976293878100         262              262   262        262
# 824839726118485274          245              245   245        245
# 1856749147915772585         188              188   188        188
# 3608475193341679870         186              186   186        186
# 3269834865385146569         152              152   152        152
# 7634897085866546110         145              145   145        145
# 720311197761340948          141              141   141        141
# 232377434237234751          134              134   134        134
# 4038076683036146727         132              132   132        132
# 3694234028523165868         122              122   122        122
# 949718915643445721          119              119   119        119
# 3525537916960843419         115              115   115        115
# 3148617623907142276         103              103   103        103
# ...

# %%
visitStartTimeFull = df[df['fullVisitorId']==1957458976293878100].sort_values(by='visitStartTime')['visitStartTime']

# %%
timeToNext = ((np.array(visitStartTimeFull[:len(visitStartTimeFull)-1]) - np.array(visitStartTimeFull[1:]))*-1)

# %%
np.append(timeToNext,0)
# Out:
# array([  91231,  324689,   14026,  100308,    5084,    2775,   65274,
#           2929,   72559,    6782,  265127,    5406,    5345,    4683,
#           4384,   61164,   84311,   22315,    2174,   54122,   20606,
#          25992,   63288,  233959,   14527,   96642,   29342,   37138,
#           4783,   21996,   58309,    6874,    4411,    5456,    3541,
#         324047,   84698,    5757,  167902,    3183,   10037,    9484,
#          66606,    2101,   17967,  323210,   85460,   15799,   86862,
#           3673,  592073,    4477,    5717,   84886,  428975,   74095,
#          11509,  592761,   15315,  271945,   84090,   63979,   22127,
#          60855,   12653,   13063,   61385,  347020,  690459,   20567,
#           6202,   83144,  174106,  257410,   63570,    7652,  279917,
#         242959,   73472,  112222,   61078,  529892,    8030,    8348,
#          78842,   68277,   14077,  255415,   18582,  328476,   12425,
# ...

# %%
timeSinceLast = (np.array(visitStartTimeFull[1:]) - np.array(visitStartTimeFull[:len(visitStartTimeFull)-1]))

# %%
np.append(0,timeSinceLast)
# Out:
# array([      0,   91231,  324689,   14026,  100308,    5084,    2775,
#          65274,    2929,   72559,    6782,  265127,    5406,    5345,
#           4683,    4384,   61164,   84311,   22315,    2174,   54122,
#          20606,   25992,   63288,  233959,   14527,   96642,   29342,
#          37138,    4783,   21996,   58309,    6874,    4411,    5456,
#           3541,  324047,   84698,    5757,  167902,    3183,   10037,
#           9484,   66606,    2101,   17967,  323210,   85460,   15799,
#          86862,    3673,  592073,    4477,    5717,   84886,  428975,
#          74095,   11509,  592761,   15315,  271945,   84090,   63979,
#          22127,   60855,   12653,   13063,   61385,  347020,  690459,
#          20567,    6202,   83144,  174106,  257410,   63570,    7652,
#         279917,  242959,   73472,  112222,   61078,  529892,    8030,
#           8348,   78842,   68277,   14077,  255415,   18582,  328476,
# ...

# %%
TS_DF = df.sort_values(by=['fullVisitorId','visitNumber']).filter(['fullVisitorId','visitNumber','visitStartTime'])

# %%
new_diff_data=pd.DataFrame(timeToNext=[],timeSinceLast=[])
#for visitorID in TS_DF['fullVisitorId'].tolist():
# Out:
# [4823595352351,
#  5103959234087,
#  10278554503158,
#  20424342248747,
#  26722803385797,
#  27376579751715,
#  33471059618621,
#  35794135966385,
#  39460501403861,
#  40862739425590,
#  40862739425590,
#  45417921646651,
#  47810105303746,
#  48421062322244,
#  52246474382344,
#  58970809397690,
#  61609983499251,
#  62267706107999,
#  62349695125717,
#  63834990385751,
#  64767209884626,
#  64767209884626,
#  68403966359845,
#  72202462202136,
#  75746323734481,
#  77980744724824,
#  82001414223176,
#  85059828173212,
#  90085033332104,
#  90134415725564,
#  93957001069502,
#  95855025602688,
#  97118899221776,
#  101322961649621,
#  109798218040435,
#  109798218040435,
#  113091074918758,
#  113091074918758,
#  114156543135683,
#  120513263852408,
#  120513263852408,
#  123950480336950,
#  132848834502720,
#  139156957304532,
#  142967912891615,
#  143747325766784,
#  144663615238931,
#  150357983459565,
#  152474579038632,
#  152560646457113,
#  158916953288213,
# ...
